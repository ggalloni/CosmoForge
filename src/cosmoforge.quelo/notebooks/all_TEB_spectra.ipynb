# %% [markdown]
# # TEB QML Power Spectrum Analysis
#
# This notebook provides a step-by-step analysis of QML power spectrum estimation for TEB (Temperature-E-B mode) polarization data.

# %% [markdown]
# ## 1. Import Required Libraries

# %%
import os
import time

import matplotlib.pyplot as plt
import numpy as np
from astropy.io import fits
from mpi4py import MPI

# Import cosmocore modules
from cosmocore import (
    InputParams,
    do_derivative_step,
    matrix_mult,
    matrix_trace,
)

# Import quelo modules
from quelo import Spectra


# Set up plotting style
plt.style.use("default")
plt.rcParams["figure.figsize"] = (12, 8)

print("All imports successful!")
print(f"MPI size: {MPI.COMM_WORLD.Get_size()}, rank: {MPI.COMM_WORLD.Get_rank()}")
# Out:
# All imports successful!
# MPI size: 1, rank: 0

# %%
def configure_plt():
    plt.rc("axes", labelsize=20, linewidth=1.5)
    plt.rc("xtick", direction="in", labelsize=15, top=True)
    plt.rc("ytick", direction="in", labelsize=15, right=True)

    plt.rc("xtick.major", width=1.1, size=5)
    plt.rc("ytick.major", width=1.1, size=5)

    plt.rc("xtick.minor", width=1.1, size=3)
    plt.rc("ytick.minor", width=1.1, size=3)

    plt.rc("lines", linewidth=2)
    plt.rc("legend", frameon=False, fontsize=15)
    plt.rc("figure", dpi=100, autolayout=True, figsize=[10, 7])
    plt.rc("savefig", dpi=300, bbox="tight")


configure_plt()

# %% [markdown]
# ## 2. Setup Test Parameters and Configuration

# %%
# Set up test configuration paths
local_path = os.path.abspath(os.getcwd())
fields = "TEB"  # Use TEB configuration for debugging
nside = 4
param_file = f"{local_path}/../tests/data/nside{nside}/{fields}/config.yaml"

print(f"Local path: {local_path}")
print(f"Parameter file: {param_file}")
print(f"Parameter file exists: {os.path.exists(param_file)}")

# Load parameters
params = InputParams.read_parameter_file(param_file)

# Display key parameters
print("\n=== Key Parameters ===")
print(f"nside: {params.nside}")
print(f"spins: {params.spins}")
print(f"labels: {getattr(params, 'labels', 'Not specified')}")
print(f"nspectra: {params.nspectra}")
print(f"lmax: {params.lmax}")
print(f"nsims: {params.nsims}")
print(f"do_cross: {params.do_cross}")
print(f"calibration: {params.calibration}")
# Out:
# Local path: /home/ggalloni/Projects/GitHub/CosmoForge/src/cosmoforge.quelo/notebooks
# Parameter file: /home/ggalloni/Projects/GitHub/CosmoForge/src/cosmoforge.quelo/notebooks/../tests/data/nside4/TEB/config.yaml
# Parameter file exists: True
#
# === Key Parameters ===
# nside: 4
# spins: [0, 0, 0]
# labels: ['T', 'E', 'B']
# nspectra: 6
# lmax: 16
# nsims: 300
# do_cross: False
# calibration: 1.0

# %% [markdown]
# ## 3. Initialize Spectra Instance

# %%
# Initialize Spectra instance
print("Creating Spectra instance...")
spectra = Spectra(param_file)

# Display MPI and basic info
print(f"MPI rank: {spectra.rank}")
print(f"MPI size: {spectra.size}")
print(f"Parameters loaded: {spectra.params is not None}")
print(f"Fisher instance created: {spectra.fisher_instance is not None}")

# Display initial variable states
print("\n=== Initial Variable States ===")
print(f"maps1: {spectra.maps1}")
print(f"maps2: {spectra.maps2}")
print(f"y: {spectra.y}")
print(f"ynb: {spectra.ynb}")
print(f"invfisher: {spectra.invfisher}")
# Out:
# Creating Spectra instance...
# Starting Fisher matrix computation...
# Starting Fisher matrix analysis pipeline
# --------------------------------------------------------------------------------
# Fisher matrix computation completed
# Fisher matrix computation completed in 13.59 seconds
# MPI rank: 0
# MPI size: 1
# Parameters loaded: True
# Fisher instance created: True
#
# === Initial Variable States ===
# maps1: None
# maps2: None
# y: None
# ynb: None
# invfisher: None
# --------------------------------------------------------------------------------
# Fisher matrix computation completed
# Fisher matrix computation completed in 13.59 seconds
# MPI rank: 0
# MPI size: 1
# Parameters loaded: True
# Fisher instance created: True
#
# === Initial Variable States ===
# maps1: None
# maps2: None
# y: None
# ynb: None
# invfisher: None

# %% [markdown]
# ## 4. Setup Fields and Geometry

# %%
# Execute setup_fields() and setup_geometry()
print("=== Setting up fields ===")
spectra.setup_fields()
print("Fields setup completed")

print("\n=== Setting up geometry ===")
spectra.setup_geometry()
print("Geometry setup completed")

# Inspect results
print("\n=== Geometry Results ===")
print(f"nside: {params.nside}")
print(f"Total pixels: {params.nside**2 * 12}")
print(f"npixs type: {type(spectra.npixs)}")
print(f"npixs: {spectra.npixs}")
print(f"n_active: {spectra.collection.n_active}")
print(f"Total pixels: {sum(spectra.collection.n_active)}")

if hasattr(spectra, "pixact") and spectra.pixact is not None:
    print(f"pixact type: {type(spectra.pixact)}")
    print(f"pixact length: {len(spectra.pixact)}")
    for i, pix in enumerate(spectra.pixact):
        print(
            f"  Field {i}: {len(pix) if hasattr(pix, '__len__') else pix} active pixels"
        )

# Check collection and spectra labels
if hasattr(spectra, "collection") and spectra.collection is not None:
    print(f"\nSpectra labels: {spectra.collection.spectra_labels}")
    print(f"Number of spectra: {len(spectra.collection.spectra_labels)}")

    # This is the KEY issue we're investigating
    print('Expected spectra: ["TT", "EE", "BB", "TE", "TB", "EB"]')
    print(f"Actual spectra: {spectra.collection.spectra_labels}")
else:
    print("Collection not available")
# Out:
# === Setting up fields ===
# Fields setup completed
#
# === Setting up geometry ===
# Geometry setup completed
#
# === Geometry Results ===
# nside: 4
# Total pixels: 192
# npixs type: <class 'list'>
# npixs: [192, 192, 192]
# n_active: [192, 192, 192]
# Total pixels: 576
# pixact type: <class 'numpy.ndarray'>
# pixact length: 3
#   Field 0: 192 active pixels
#   Field 1: 192 active pixels
#   Field 2: 192 active pixels
#
# Spectra labels: ['TT', 'EE', 'BB', 'TE', 'TB', 'EB']
# Number of spectra: 6
# Expected spectra: ["TT", "EE", "BB", "TE", "TB", "EB"]
# Actual spectra: ['TT', 'EE', 'BB', 'TE', 'TB', 'EB']

# %% [markdown]
# ## 5. Load Maps Data

# %%
# Execute setup_maps() - this follows the exact pattern from spectra.run()
print("=== Loading maps ===")
# Read maps using the core functionality
ntot = sum(spectra.collection.n_active)
print(f"Total active pixels (ntot): {ntot}")
spectra.maps1 = np.empty((ntot, spectra.params.nsims), dtype=np.float64)

# Load from multi-extension FITS file
filename = f"{spectra.params.inputmapfile1.rsplit('sim', 1)[0]}all_sims_TEB.fits"
print(f"Loading from multi-extension FITS: {filename}")

with fits.open(filename) as hdul:
    print(f"Number of extensions: {len(hdul)}")
    for isim in range(spectra.params.nsims):
        ext_name = f"SIM_{isim:03d}"
        if ext_name in hdul:
            sim_data = hdul[ext_name].data
            spectra.maps1[:, isim] = np.concatenate(sim_data)
        else:
            print(f"Warning: Extension {ext_name} not found")

spectra.maps1 *= spectra.params.calibration
print("Maps loaded")

print("\n=== Maps1 Info ===")
print(f"maps1 shape: {spectra.maps1.shape}")
print(f"maps1 dtype: {spectra.maps1.dtype}")
print(f"maps1 min/max: {spectra.maps1.min():.3e} / {spectra.maps1.max():.3e}")
print(f"maps1 mean/std: {spectra.maps1.mean():.3e} / {spectra.maps1.std():.3e}")
# Out:
# === Loading maps ===
# Total active pixels (ntot): 576
# Loading from multi-extension FITS: /home/ggalloni/Projects/GitHub/CosmoForge/src/cosmoforge.quelo/tests/data/nside4/maps/all_sims_TEB.fits
# Number of extensions: 301
# Maps loaded
#
# === Maps1 Info ===
# maps1 shape: (576, 300)
# maps1 dtype: float64
# maps1 min/max: -1.677e+02 / 1.603e+02
# maps1 mean/std: 2.117e-03 / 2.330e+01
# Maps loaded
#
# === Maps1 Info ===
# maps1 shape: (576, 300)
# maps1 dtype: float64
# maps1 min/max: -1.677e+02 / 1.603e+02
# maps1 mean/std: 2.117e-03 / 2.330e+01

# %% [markdown]
# ## 6. Load Covariance Matrices

# %%
# Load covariance matrices - from spectra.run()
print("=== Loading covariance matrices ===")

ntot = sum(spectra.collection.n_active)
print(f"Total matrix size: {ntot} x {ntot}")

# Load invCov1 (inverted covariance matrix)
print(f"Loading invCov1 from: {spectra.params.outinvcovmatfile1}")
spectra.invCov1 = np.fromfile(spectra.params.outinvcovmatfile1).reshape((ntot, ntot))

# Load NCov1 (noise covariance matrix)
print(f"Loading NCov1 from: {spectra.params.covmatfile1}")
spectra.NCov1 = np.fromfile(spectra.params.covmatfile1).reshape((ntot, ntot))

# Inspect covariance matrices
print("\n=== Covariance Matrix Info ===")
print(f"invCov1 shape: {spectra.invCov1.shape}")
print(f"invCov1 dtype: {spectra.invCov1.dtype}")

print(f"\nNCov1 shape: {spectra.NCov1.shape}")
print(f"NCov1 dtype: {spectra.NCov1.dtype}")
# Out:
# === Loading covariance matrices ===
# Total matrix size: 576 x 576
# Loading invCov1 from: /home/ggalloni/Projects/GitHub/CosmoForge/src/cosmoforge.quelo/tests/data/nside4/TEB/invCOV1.bin
# Loading NCov1 from: /home/ggalloni/Projects/GitHub/CosmoForge/src/cosmoforge.quelo/tests/data/nside4/TEB/NCVM1.bin
#
# === Covariance Matrix Info ===
# invCov1 shape: (576, 576)
# invCov1 dtype: float64
#
# NCov1 shape: (576, 576)
# NCov1 dtype: float64

# %% [markdown]
# ## 7. Setup Cls and Beams

# %%
print("=== Setting up Cls ===")
spectra.setup_cls()
print("Cls setup completed")

print("\n=== Setting up beams ===")
spectra.setup_beams()
print("Beams setup completed")

# Inspect the spectra collection
print("\n=== Spectra Collection Info ===")
if hasattr(spectra, "collection") and spectra.collection is not None:
    print(f"Collection type: {type(spectra.collection)}")

    # Get spectra manager info
    if hasattr(spectra.collection, "spectra_manager"):
        mgr = spectra.collection.spectra_manager
        print(f"Spectra labels: {mgr.labels}")
        print(f"Number of spectra: {mgr.n_spectra}")

        # Show reference Cls values
        print("\n=== Reference Cls Values (first few ell) ===")
        if hasattr(mgr, "_cls_dict"):
            for label in mgr.labels:
                if label in mgr._cls_dict:
                    cls_vals = mgr._cls_dict[label]
                    print(f"{label}: {cls_vals[:5]} (ell=2-6)")

    # Get beam manager info
    if hasattr(spectra.collection, "beam_manager"):
        print(f"\nBeam manager available: {spectra.collection.beam_manager is not None}")
else:
    print("Collection not available")
# Out:
# === Setting up Cls ===
# Cls setup completed
#
# === Setting up beams ===
# Beams setup completed
#
# === Spectra Collection Info ===
# Collection type: <class 'cosmocore.fields.FieldCollection'>
# Spectra labels: ['TT', 'EE', 'BB', 'TE', 'TB', 'EB']
# Number of spectra: 6
#
# === Reference Cls Values (first few ell) ===
# TT: [421.50678481 273.79756797 194.4478264  146.59922523 115.18705562] (ell=2-6)
# EE: [0.01433965 0.01339889 0.0093084  0.00524337 0.00251814] (ell=2-6)
# BB: [7.06455616e-07 9.69680037e-07 1.21430109e-06 1.43604300e-06
#  1.63134490e-06] (ell=2-6)
# TE: [1.14567594 0.90174391 0.64820472 0.44339181 0.29454739] (ell=2-6)
# TB: [0. 0. 0. 0. 0.] (ell=2-6)
# EB: [0. 0. 0. 0. 0.] (ell=2-6)
#
# Beam manager available: True

# %% [markdown]
# ## 8. Compute Smoothing Factors and vecmul

# %%
print("=== Computing smoothing factors ===")

smoothing_factors = spectra.collection.spectra_manager.compute_smoothing_factors(
    spectra.collection.beam_manager
)

print(f"Smoothing factors computed for: {list(smoothing_factors.keys())}")

# Create vecmul array
nell = spectra.params.nspectra * (spectra.params.lmax - 1)
vecmul = np.zeros(nell, dtype=np.float64)

print(
    f"\nvecmul array size: {nell} "
    f"(nspectra={spectra.params.nspectra}, lmax-1={spectra.params.lmax - 1})"
)

# Fill vecmul array
idx = 0
for ispec, spectrum_label in enumerate(spectra.collection.spectra_manager.labels):
    print(f"\nProcessing spectrum {ispec}: {spectrum_label}")

    if spectrum_label in smoothing_factors:
        smooth_factor = smoothing_factors[spectrum_label]
        print(f"  Smoothing factors (first 5): {smooth_factor[:5]}")

        for ell_idx in range(spectra.params.lmax - 1):
            vecmul[idx] = smooth_factor[ell_idx]
            idx += 1

        print(f"  Added {spectra.params.lmax - 1} factors to vecmul")
    else:
        print(f"  ⚠️  No smoothing factors found for {spectrum_label}")

spectra.vecmul = vecmul

print("\n=== vecmul Summary ===")
print(f"vecmul shape: {spectra.vecmul.shape}")
print(f"vecmul min/max: {spectra.vecmul.min():.3e} / {spectra.vecmul.max():.3e}")
print(f"vecmul first 10 values: {spectra.vecmul[:10]}")
# Out:
# === Computing smoothing factors ===
# Smoothing factors computed for: ['TT', 'EE', 'BB', 'TE', 'TB', 'EB']
#
# vecmul array size: 90 (nspectra=6, lmax-1=15)
#
# Processing spectrum 0: TT
#   Smoothing factors (first 5): [1.02655673 0.50316117 0.29398847 0.18959571 0.13013891]
#   Added 15 factors to vecmul
#
# Processing spectrum 1: EE
#   Smoothing factors (first 5): [1.04027175 0.50988365 0.29791641 0.19212896 0.13187781]
#   Added 15 factors to vecmul
#
# Processing spectrum 2: BB
#   Smoothing factors (first 5): [1.04027175 0.50988365 0.29791641 0.19212896 0.13187781]
#   Added 15 factors to vecmul
#
# Processing spectrum 3: TE
#   Smoothing factors (first 5): [1.03339148 0.50651125 0.29594592 0.19085813 0.13100548]
#   Added 15 factors to vecmul
#
# Processing spectrum 4: TB
#   Smoothing factors (first 5): [1.03339148 0.50651125 0.29594592 0.19085813 0.13100548]
#   Added 15 factors to vecmul
#
# Processing spectrum 5: EB
#   Smoothing factors (first 5): [1.04027175 0.50988365 0.29791641 0.19212896 0.13187781]
#   Added 15 factors to vecmul
#
# === vecmul Summary ===
# vecmul shape: (90,)
# vecmul min/max: 9.365e-03 / 1.040e+00
# vecmul first 10 values: [1.02655673 0.50316117 0.29398847 0.18959571 0.13013891 0.09317342
#  0.0687207  0.05178853 0.03965106 0.03071566]

# %% [markdown]
# ## 9. Load and Process Fisher Matrix

# %%
print("=== Loading Fisher matrix ===")

# Load Fisher matrix
print(f"Loading Fisher from: {spectra.params.outfilefisher}")
spectra.invfisher = np.loadtxt(spectra.params.outfilefisher)

print(f"Fisher shape: {spectra.invfisher.shape}")
print(f"Fisher diagonal (first 5): {np.diag(spectra.invfisher)[:5]}")

print("\n=== Applying vecmul normalization ===")
nell = len(spectra.vecmul)
print(f"Applying normalization to {nell} x {nell} matrix")

print("Before normalization:")
print(f"  Fisher[0,0]: {spectra.invfisher[0, 0]:.3e}")
print(f"  vecmul[0]: {spectra.vecmul[0]:.3e}")

# Apply normalization
spectra.invfisher = spectra.invfisher * np.outer(spectra.vecmul, spectra.vecmul)

# Invert the normalized Fisher matrix
print("\n=== Inverting Fisher matrix ===")
spectra.invfisher = np.linalg.inv(spectra.invfisher)
# Out:
# === Loading Fisher matrix ===
# Loading Fisher from: /home/ggalloni/Projects/GitHub/CosmoForge/src/cosmoforge.quelo/tests/data/nside4/TEB/fisher.dat
# Fisher shape: (90, 90)
# Fisher diagonal (first 5): [3.6329546e-06 2.3887902e-05 1.0314162e-04 3.5182213e-04 1.0461465e-03]
#
# === Applying vecmul normalization ===
# Applying normalization to 90 x 90 matrix
# Before normalization:
#   Fisher[0,0]: 3.633e-06
#   vecmul[0]: 1.027e+00
#
# === Inverting Fisher matrix ===

# %% [markdown]
# ## 10. Initialize QML Variables

# %%
print("=== Initializing QML variables ===")

nell = spectra.params.nspectra * (spectra.params.lmax - 1)

# Initialize y vectors for QML estimation
spectra.y = np.zeros((spectra.params.nsims, nell), dtype=np.float64)
print(f"Initialized y array: shape={spectra.y.shape}, dtype={spectra.y.dtype}")

spectra.ynb = np.zeros(nell, dtype=np.float64)
print(f"Initialized ynb array: shape={spectra.ynb.shape}, dtype={spectra.ynb.dtype}")

# Prepare for main computation loop
ntot = sum(spectra.collection.n_active)
print("\n=== Computation Setup ===")
print(f"Total matrix size: {ntot}")
print(f"Number of multipole bins: {nell}")
print(f"Number of simulations: {spectra.params.nsims}")
print(f"MPI size: {spectra.size}")

# Allocate working arrays
der_s = np.zeros((ntot, ntot), dtype=np.float64)
E = np.zeros((ntot, ntot), dtype=np.float64)
print(f"Allocated working matrices: {der_s.shape}, {E.shape}")

print("\n✅ All variables initialized and ready for computation")
# Out:
# === Initializing QML variables ===
# Initialized y array: shape=(300, 90), dtype=float64
# Initialized ynb array: shape=(90,), dtype=float64
#
# === Computation Setup ===
# Total matrix size: 576
# Number of multipole bins: 90
# Number of simulations: 300
# MPI size: 1
# Allocated working matrices: (576, 576), (576, 576)
#
# ✅ All variables initialized and ready for computation

# %% [markdown]
# ## 11. Main QML Computation Loop

# %%
print("=== Starting main QML computation ===")

nell = spectra.params.nspectra * (spectra.params.lmax - 1)
ntot = sum(spectra.collection.n_active)

# Allocate derivative matrix
der_s = np.zeros((ntot, ntot), dtype=np.float64)
E = np.zeros((ntot, ntot), dtype=np.float64)

start_time = time.time()

print(f"Processing {nell} multipole bins...")

# Track computation for debugging
computation_info = []

for il in range(nell):
    print(f"\n--- Processing bin {il} ---")

    # Compute derivative of signal matrix for this multipole
    spectrum_idx = il // (spectra.params.lmax - 1)
    ell = (il % (spectra.params.lmax - 1)) + 2

    spec_label = spectra.collection.spectra_labels[spectrum_idx]

    print(f"  Spectrum {spectrum_idx}: {spec_label}, ell={ell}")

    # This is where the derivative computation happens
    do_derivative_step(
        der_s,
        spectrum_idx,
        spectra.npixs,
        spectra.params.spins,
        ell,
        spectra.collection,
    )

    # Compute E matrix
    E = 0.5 * matrix_mult(spectra.invCov1, matrix_mult(der_s, spectra.invCov1))

    # Compute noise bias
    tr_ne = matrix_trace(spectra.NCov1, E)
    spectra.ynb[il] = tr_ne

    # Compute signal for each simulation
    for field_idx in range(spectra.params.nsims):
        spectra.y[field_idx, il] = matrix_mult(
            spectra.maps1[:, field_idx].T, matrix_mult(E, spectra.maps1[:, field_idx])
        )

    # Subtract noise bias
    for field_idx in range(spectra.params.nsims):
        spectra.y[field_idx, il] = spectra.y[field_idx, il] - spectra.ynb[il]

    # Store info for analysis
    info = {
        "il": il,
        "spectrum": spec_label,
        "ell": ell,
        "noise_bias": spectra.ynb[il],
        "signal_sim0": spectra.y[0, il],
        "der_s_trace": np.trace(der_s),
        "E_trace": np.trace(E),
    }
    computation_info.append(info)

    print(f"  Noise bias: {spectra.ynb[il]:.3e}")
    print(f"  Signal (sim 0): {spectra.y[0, il]:.3e}")

elapsed = time.time() - start_time
print(f"\nComputation completed in {elapsed:.2f} seconds")
# Out:
# === Starting main QML computation ===
# Processing 90 multipole bins...
#
# --- Processing bin 0 ---
#   Spectrum 0: TT, ell=2
#   Noise bias: 2.049e-07
#   Signal (sim 0): 5.353e-03
#
# --- Processing bin 1 ---
#   Spectrum 0: TT, ell=3
#   Noise bias: 2.049e-07
#   Signal (sim 0): 5.353e-03
#
# --- Processing bin 1 ---
#   Spectrum 0: TT, ell=3
#   Noise bias: 9.838e-07
#   Signal (sim 0): 1.546e-02
#
# --- Processing bin 2 ---
#   Spectrum 0: TT, ell=4
#   Noise bias: 9.838e-07
#   Signal (sim 0): 1.546e-02
#
# --- Processing bin 2 ---
#   Spectrum 0: TT, ell=4
#   Noise bias: 4.436e-06
#   Signal (sim 0): 1.110e-02
#
# --- Processing bin 3 ---
#   Spectrum 0: TT, ell=5
#   Noise bias: 4.436e-06
#   Signal (sim 0): 1.110e-02
#
# --- Processing bin 3 ---
#   Spectrum 0: TT, ell=5
#   Noise bias: 2.212e-05
#   Signal (sim 0): 5.058e-02
#
# --- Processing bin 4 ---
#   Spectrum 0: TT, ell=6
#   Noise bias: 1.228e-04
#   Signal (sim 0): 4.757e-02
#
# --- Processing bin 5 ---
#   Spectrum 0: TT, ell=7
#   Noise bias: 2.212e-05
#   Signal (sim 0): 5.058e-02
#
# --- Processing bin 4 ---
#   Spectrum 0: TT, ell=6
#   Noise bias: 1.228e-04
#   Signal (sim 0): 4.757e-02
#
# --- Processing bin 5 ---
#   Spectrum 0: TT, ell=7
#   Noise bias: 7.108e-04
#   Signal (sim 0): 9.616e-02
#
# --- Processing bin 6 ---
#   Spectrum 0: TT, ell=8
#   Noise bias: 2.439e-03
#   Signal (sim 0): 2.367e-01
#
# --- Processing bin 7 ---
#   Spectrum 0: TT, ell=9
#   Noise bias: 4.410e-03
#   Signal (sim 0): 2.968e-01
#
# --- Processing bin 8 ---
#   Spectrum 0: TT, ell=10
#   Noise bias: 7.108e-04
#   Signal (sim 0): 9.616e-02
#
# --- Processing bin 6 ---
#   Spectrum 0: TT, ell=8
#   Noise bias: 2.439e-03
#   Signal (sim 0): 2.367e-01
#
# --- Processing bin 7 ---
#   Spectrum 0: TT, ell=9
#   Noise bias: 4.410e-03
#   Signal (sim 0): 2.968e-01
#
# --- Processing bin 8 ---
#   Spectrum 0: TT, ell=10
#   Noise bias: 6.009e-03
#   Signal (sim 0): 3.615e-01
#
# --- Processing bin 9 ---
#   Spectrum 0: TT, ell=11
#   Noise bias: 6.009e-03
#   Signal (sim 0): 3.615e-01
#
# --- Processing bin 9 ---
#   Spectrum 0: TT, ell=11
#   Noise bias: 1.053e-02
#   Signal (sim 0): 3.484e-01
#
# --- Processing bin 10 ---
#   Spectrum 0: TT, ell=12
#   Noise bias: 1.053e-02
#   Signal (sim 0): 3.484e-01
#
# --- Processing bin 10 ---
#   Spectrum 0: TT, ell=12
#   Noise bias: 1.720e-02
#   Signal (sim 0): 5.461e-01
#
# --- Processing bin 11 ---
#   Spectrum 0: TT, ell=13
#   Noise bias: 2.917e-02
#   Signal (sim 0): 5.984e-01
#
# --- Processing bin 12 ---
#   Spectrum 0: TT, ell=14
#   Noise bias: 1.720e-02
#   Signal (sim 0): 5.461e-01
#
# --- Processing bin 11 ---
#   Spectrum 0: TT, ell=13
#   Noise bias: 2.917e-02
#   Signal (sim 0): 5.984e-01
#
# --- Processing bin 12 ---
#   Spectrum 0: TT, ell=14
#   Noise bias: 3.112e-02
#   Signal (sim 0): 1.292e+00
#
# --- Processing bin 13 ---
#   Spectrum 0: TT, ell=15
#   Noise bias: 4.061e-02
#   Signal (sim 0): 5.856e-01
#
# --- Processing bin 14 ---
#   Spectrum 0: TT, ell=16
#   Noise bias: 3.112e-02
#   Signal (sim 0): 1.292e+00
#
# --- Processing bin 13 ---
#   Spectrum 0: TT, ell=15
#   Noise bias: 4.061e-02
#   Signal (sim 0): 5.856e-01
#
# --- Processing bin 14 ---
#   Spectrum 0: TT, ell=16
#   Noise bias: 3.029e-02
#   Signal (sim 0): 5.198e-01
#
# --- Processing bin 15 ---
#   Spectrum 1: EE, ell=2
#   Noise bias: 3.029e-02
#   Signal (sim 0): 5.198e-01
#
# --- Processing bin 15 ---
#   Spectrum 1: EE, ell=2
#   Noise bias: 2.662e-02
#   Signal (sim 0): 2.190e+02
#
# --- Processing bin 16 ---
#   Spectrum 1: EE, ell=3
#   Noise bias: 2.662e-02
#   Signal (sim 0): 2.190e+02
#
# --- Processing bin 16 ---
#   Spectrum 1: EE, ell=3
#   Noise bias: 8.465e-02
#   Signal (sim 0): 1.796e+02
#
# --- Processing bin 17 ---
#   Spectrum 1: EE, ell=4
#   Noise bias: 8.465e-02
#   Signal (sim 0): 1.796e+02
#
# --- Processing bin 17 ---
#   Spectrum 1: EE, ell=4
#   Noise bias: 3.826e-01
#   Signal (sim 0): 2.199e+02
#
# --- Processing bin 18 ---
#   Spectrum 1: EE, ell=5
#   Noise bias: 2.341e+00
#   Signal (sim 0): 4.273e+02
#
# --- Processing bin 19 ---
#   Spectrum 1: EE, ell=6
#   Noise bias: 1.873e+01
#   Signal (sim 0): 3.472e+03
#
# --- Processing bin 20 ---
#   Spectrum 1: EE, ell=7
#   Noise bias: 3.826e-01
#   Signal (sim 0): 2.199e+02
#
# --- Processing bin 18 ---
#   Spectrum 1: EE, ell=5
#   Noise bias: 2.341e+00
#   Signal (sim 0): 4.273e+02
#
# --- Processing bin 19 ---
#   Spectrum 1: EE, ell=6
#   Noise bias: 1.873e+01
#   Signal (sim 0): 3.472e+03
#
# --- Processing bin 20 ---
#   Spectrum 1: EE, ell=7
#   Noise bias: 1.660e+02
#   Signal (sim 0): 4.179e+03
#
# --- Processing bin 21 ---
#   Spectrum 1: EE, ell=8
#   Noise bias: 9.153e+02
#   Signal (sim 0): 2.159e+04
#
# --- Processing bin 22 ---
#   Spectrum 1: EE, ell=9
#   Noise bias: 2.469e+03
#   Signal (sim 0): 2.462e+04
#
# --- Processing bin 23 ---
#   Spectrum 1: EE, ell=10
#   Noise bias: 1.660e+02
#   Signal (sim 0): 4.179e+03
#
# --- Processing bin 21 ---
#   Spectrum 1: EE, ell=8
#   Noise bias: 9.153e+02
#   Signal (sim 0): 2.159e+04
#
# --- Processing bin 22 ---
#   Spectrum 1: EE, ell=9
#   Noise bias: 2.469e+03
#   Signal (sim 0): 2.462e+04
#
# --- Processing bin 23 ---
#   Spectrum 1: EE, ell=10
#   Noise bias: 4.459e+03
#   Signal (sim 0): 7.007e+04
#
# --- Processing bin 24 ---
#   Spectrum 1: EE, ell=11
#   Noise bias: 9.103e+03
#   Signal (sim 0): 5.474e+04
#
# --- Processing bin 25 ---
#   Spectrum 1: EE, ell=12
#   Noise bias: 1.482e+04
#   Signal (sim 0): 1.025e+05
#
# --- Processing bin 26 ---
#   Spectrum 1: EE, ell=13
#   Noise bias: 4.459e+03
#   Signal (sim 0): 7.007e+04
#
# --- Processing bin 24 ---
#   Spectrum 1: EE, ell=11
#   Noise bias: 9.103e+03
#   Signal (sim 0): 5.474e+04
#
# --- Processing bin 25 ---
#   Spectrum 1: EE, ell=12
#   Noise bias: 1.482e+04
#   Signal (sim 0): 1.025e+05
#
# --- Processing bin 26 ---
#   Spectrum 1: EE, ell=13
#   Noise bias: 2.465e+04
#   Signal (sim 0): 1.140e+05
#
# --- Processing bin 27 ---
#   Spectrum 1: EE, ell=14
#   Noise bias: 2.465e+04
#   Signal (sim 0): 1.140e+05
#
# --- Processing bin 27 ---
#   Spectrum 1: EE, ell=14
#   Noise bias: 2.425e+04
#   Signal (sim 0): 1.620e+05
#
# --- Processing bin 28 ---
#   Spectrum 1: EE, ell=15
#   Noise bias: 2.425e+04
#   Signal (sim 0): 1.620e+05
#
# --- Processing bin 28 ---
#   Spectrum 1: EE, ell=15
#   Noise bias: 3.111e+04
#   Signal (sim 0): 1.864e+05
#
# --- Processing bin 29 ---
#   Spectrum 1: EE, ell=16
#   Noise bias: 3.111e+04
#   Signal (sim 0): 1.864e+05
#
# --- Processing bin 29 ---
#   Spectrum 1: EE, ell=16
#   Noise bias: 2.205e+04
#   Signal (sim 0): 4.051e+04
#
# --- Processing bin 30 ---
#   Spectrum 2: BB, ell=2
#   Noise bias: 2.012e+05
#   Signal (sim 0): -6.161e+04
#
# --- Processing bin 31 ---
#   Spectrum 2: BB, ell=3
#   Noise bias: 2.837e+05
#   Signal (sim 0): -4.995e+04
#
# --- Processing bin 32 ---
#   Spectrum 2: BB, ell=4
#   Noise bias: 3.665e+05
#   Signal (sim 0): -2.733e+04
#
# --- Processing bin 33 ---
#   Spectrum 2: BB, ell=5
#   Noise bias: 2.205e+04
#   Signal (sim 0): 4.051e+04
#
# --- Processing bin 30 ---
#   Spectrum 2: BB, ell=2
#   Noise bias: 2.012e+05
#   Signal (sim 0): -6.161e+04
#
# --- Processing bin 31 ---
#   Spectrum 2: BB, ell=3
#   Noise bias: 2.837e+05
#   Signal (sim 0): -4.995e+04
#
# --- Processing bin 32 ---
#   Spectrum 2: BB, ell=4
#   Noise bias: 3.665e+05
#   Signal (sim 0): -2.733e+04
#
# --- Processing bin 33 ---
#   Spectrum 2: BB, ell=5
#   Noise bias: 4.530e+05
#   Signal (sim 0): -3.580e+05
#
# --- Processing bin 34 ---
#   Spectrum 2: BB, ell=6
#   Noise bias: 4.530e+05
#   Signal (sim 0): -3.580e+05
#
# --- Processing bin 34 ---
#   Spectrum 2: BB, ell=6
#   Noise bias: 5.377e+05
#   Signal (sim 0): 1.692e+05
#
# --- Processing bin 35 ---
#   Spectrum 2: BB, ell=7
#   Noise bias: 5.377e+05
#   Signal (sim 0): 1.692e+05
#
# --- Processing bin 35 ---
#   Spectrum 2: BB, ell=7
#   Noise bias: 6.295e+05
#   Signal (sim 0): 3.718e+05
#
# --- Processing bin 36 ---
#   Spectrum 2: BB, ell=8
#   Noise bias: 6.295e+05
#   Signal (sim 0): 3.718e+05
#
# --- Processing bin 36 ---
#   Spectrum 2: BB, ell=8
#   Noise bias: 6.794e+05
#   Signal (sim 0): -3.084e+05
#
# --- Processing bin 37 ---
#   Spectrum 2: BB, ell=9
#   Noise bias: 7.718e+05
#   Signal (sim 0): 1.712e+05
#
# --- Processing bin 38 ---
#   Spectrum 2: BB, ell=10
#   Noise bias: 8.260e+05
#   Signal (sim 0): 2.628e+05
#
# --- Processing bin 39 ---
#   Spectrum 2: BB, ell=11
#   Noise bias: 9.202e+05
#   Signal (sim 0): -9.352e+04
#
# --- Processing bin 40 ---
#   Spectrum 2: BB, ell=12
#   Noise bias: 6.794e+05
#   Signal (sim 0): -3.084e+05
#
# --- Processing bin 37 ---
#   Spectrum 2: BB, ell=9
#   Noise bias: 7.718e+05
#   Signal (sim 0): 1.712e+05
#
# --- Processing bin 38 ---
#   Spectrum 2: BB, ell=10
#   Noise bias: 8.260e+05
#   Signal (sim 0): 2.628e+05
#
# --- Processing bin 39 ---
#   Spectrum 2: BB, ell=11
#   Noise bias: 9.202e+05
#   Signal (sim 0): -9.352e+04
#
# --- Processing bin 40 ---
#   Spectrum 2: BB, ell=12
#   Noise bias: 9.794e+05
#   Signal (sim 0): 3.204e+05
#
# --- Processing bin 41 ---
#   Spectrum 2: BB, ell=13
#   Noise bias: 9.794e+05
#   Signal (sim 0): 3.204e+05
#
# --- Processing bin 41 ---
#   Spectrum 2: BB, ell=13
#   Noise bias: 1.076e+06
#   Signal (sim 0): -1.007e+05
#
# --- Processing bin 42 ---
#   Spectrum 2: BB, ell=14
#   Noise bias: 1.076e+06
#   Signal (sim 0): -1.007e+05
#
# --- Processing bin 42 ---
#   Spectrum 2: BB, ell=14
#   Noise bias: 1.132e+06
#   Signal (sim 0): -3.420e+04
#
# --- Processing bin 43 ---
#   Spectrum 2: BB, ell=15
#   Noise bias: 1.132e+06
#   Signal (sim 0): -3.420e+04
#
# --- Processing bin 43 ---
#   Spectrum 2: BB, ell=15
#   Noise bias: 1.231e+06
#   Signal (sim 0): 1.341e+03
#
# --- Processing bin 44 ---
#   Spectrum 2: BB, ell=16
#   Noise bias: 1.274e+06
#   Signal (sim 0): 1.813e+05
#
# --- Processing bin 45 ---
#   Spectrum 3: TE, ell=2
#   Noise bias: -1.448e-04
#   Signal (sim 0): -1.949e+00
#
# --- Processing bin 46 ---
#   Spectrum 3: TE, ell=3
#   Noise bias: -5.598e-04
#   Signal (sim 0): 1.477e-01
#
# --- Processing bin 47 ---
#   Spectrum 3: TE, ell=4
#   Noise bias: -2.558e-03
#   Signal (sim 0): -7.671e-01
#
# --- Processing bin 48 ---
#   Spectrum 3: TE, ell=5
#   Noise bias: 1.231e+06
#   Signal (sim 0): 1.341e+03
#
# --- Processing bin 44 ---
#   Spectrum 2: BB, ell=16
#   Noise bias: 1.274e+06
#   Signal (sim 0): 1.813e+05
#
# --- Processing bin 45 ---
#   Spectrum 3: TE, ell=2
#   Noise bias: -1.448e-04
#   Signal (sim 0): -1.949e+00
#
# --- Processing bin 46 ---
#   Spectrum 3: TE, ell=3
#   Noise bias: -5.598e-04
#   Signal (sim 0): 1.477e-01
#
# --- Processing bin 47 ---
#   Spectrum 3: TE, ell=4
#   Noise bias: -2.558e-03
#   Signal (sim 0): -7.671e-01
#
# --- Processing bin 48 ---
#   Spectrum 3: TE, ell=5
#   Noise bias: -1.417e-02
#   Signal (sim 0): 1.399e+00
#
# --- Processing bin 49 ---
#   Spectrum 3: TE, ell=6
#   Noise bias: -1.417e-02
#   Signal (sim 0): 1.399e+00
#
# --- Processing bin 49 ---
#   Spectrum 3: TE, ell=6
#   Noise bias: -9.550e-02
#   Signal (sim 0): -9.877e+00
#
# --- Processing bin 50 ---
#   Spectrum 3: TE, ell=7
#   Noise bias: -6.848e-01
#   Signal (sim 0): -8.372e+00
#
# --- Processing bin 51 ---
#   Spectrum 3: TE, ell=8
#   Noise bias: -2.978e+00
#   Signal (sim 0): -5.447e+01
#
# --- Processing bin 52 ---
#   Spectrum 3: TE, ell=9
#   Noise bias: -6.554e+00
#   Signal (sim 0): -7.001e+01
#
# --- Processing bin 53 ---
#   Spectrum 3: TE, ell=10
#   Noise bias: -9.550e-02
#   Signal (sim 0): -9.877e+00
#
# --- Processing bin 50 ---
#   Spectrum 3: TE, ell=7
#   Noise bias: -6.848e-01
#   Signal (sim 0): -8.372e+00
#
# --- Processing bin 51 ---
#   Spectrum 3: TE, ell=8
#   Noise bias: -2.978e+00
#   Signal (sim 0): -5.447e+01
#
# --- Processing bin 52 ---
#   Spectrum 3: TE, ell=9
#   Noise bias: -6.554e+00
#   Signal (sim 0): -7.001e+01
#
# --- Processing bin 53 ---
#   Spectrum 3: TE, ell=10
#   Noise bias: -1.032e+01
#   Signal (sim 0): -2.244e+02
#
# --- Processing bin 54 ---
#   Spectrum 3: TE, ell=11
#   Noise bias: -1.032e+01
#   Signal (sim 0): -2.244e+02
#
# --- Processing bin 54 ---
#   Spectrum 3: TE, ell=11
#   Noise bias: -1.945e+01
#   Signal (sim 0): -4.684e+01
#
# --- Processing bin 55 ---
#   Spectrum 3: TE, ell=12
#   Noise bias: -3.182e+01
#   Signal (sim 0): -3.358e+02
#
# --- Processing bin 56 ---
#   Spectrum 3: TE, ell=13
#   Noise bias: -1.945e+01
#   Signal (sim 0): -4.684e+01
#
# --- Processing bin 55 ---
#   Spectrum 3: TE, ell=12
#   Noise bias: -3.182e+01
#   Signal (sim 0): -3.358e+02
#
# --- Processing bin 56 ---
#   Spectrum 3: TE, ell=13
#   Noise bias: -5.324e+01
#   Signal (sim 0): -2.688e+02
#
# --- Processing bin 57 ---
#   Spectrum 3: TE, ell=14
#   Noise bias: -5.473e+01
#   Signal (sim 0): -6.611e+02
#
# --- Processing bin 58 ---
#   Spectrum 3: TE, ell=15
#   Noise bias: -7.022e+01
#   Signal (sim 0): -3.911e+02
#
# --- Processing bin 59 ---
#   Spectrum 3: TE, ell=16
#   Noise bias: -5.324e+01
#   Signal (sim 0): -2.688e+02
#
# --- Processing bin 57 ---
#   Spectrum 3: TE, ell=14
#   Noise bias: -5.473e+01
#   Signal (sim 0): -6.611e+02
#
# --- Processing bin 58 ---
#   Spectrum 3: TE, ell=15
#   Noise bias: -7.022e+01
#   Signal (sim 0): -3.911e+02
#
# --- Processing bin 59 ---
#   Spectrum 3: TE, ell=16
#   Noise bias: -5.111e+01
#   Signal (sim 0): -8.855e+01
#
# --- Processing bin 60 ---
#   Spectrum 4: TB, ell=2
#   Noise bias: 0.000e+00
#   Signal (sim 0): -8.467e+00
#
# --- Processing bin 61 ---
#   Spectrum 4: TB, ell=3
#   Noise bias: -5.111e+01
#   Signal (sim 0): -8.855e+01
#
# --- Processing bin 60 ---
#   Spectrum 4: TB, ell=2
#   Noise bias: 0.000e+00
#   Signal (sim 0): -8.467e+00
#
# --- Processing bin 61 ---
#   Spectrum 4: TB, ell=3
#   Noise bias: 0.000e+00
#   Signal (sim 0): 2.022e+01
#
# --- Processing bin 62 ---
#   Spectrum 4: TB, ell=4
#   Noise bias: 0.000e+00
#   Signal (sim 0): -8.346e+00
#
# --- Processing bin 63 ---
#   Spectrum 4: TB, ell=5
#   Noise bias: 0.000e+00
#   Signal (sim 0): 2.022e+01
#
# --- Processing bin 62 ---
#   Spectrum 4: TB, ell=4
#   Noise bias: 0.000e+00
#   Signal (sim 0): -8.346e+00
#
# --- Processing bin 63 ---
#   Spectrum 4: TB, ell=5
#   Noise bias: 0.000e+00
#   Signal (sim 0): 3.793e+00
#
# --- Processing bin 64 ---
#   Spectrum 4: TB, ell=6
#   Noise bias: 0.000e+00
#   Signal (sim 0): 8.307e+01
#
# --- Processing bin 65 ---
#   Spectrum 4: TB, ell=7
#   Noise bias: 0.000e+00
#   Signal (sim 0): -3.731e+01
#
# --- Processing bin 66 ---
#   Spectrum 4: TB, ell=8
#   Noise bias: 0.000e+00
#   Signal (sim 0): 3.793e+00
#
# --- Processing bin 64 ---
#   Spectrum 4: TB, ell=6
#   Noise bias: 0.000e+00
#   Signal (sim 0): 8.307e+01
#
# --- Processing bin 65 ---
#   Spectrum 4: TB, ell=7
#   Noise bias: 0.000e+00
#   Signal (sim 0): -3.731e+01
#
# --- Processing bin 66 ---
#   Spectrum 4: TB, ell=8
#   Noise bias: 0.000e+00
#   Signal (sim 0): 2.199e+02
#
# --- Processing bin 67 ---
#   Spectrum 4: TB, ell=9
#   Noise bias: 0.000e+00
#   Signal (sim 0): 1.437e+02
#
# --- Processing bin 68 ---
#   Spectrum 4: TB, ell=10
#   Noise bias: 0.000e+00
#   Signal (sim 0): 2.199e+02
#
# --- Processing bin 67 ---
#   Spectrum 4: TB, ell=9
#   Noise bias: 0.000e+00
#   Signal (sim 0): 1.437e+02
#
# --- Processing bin 68 ---
#   Spectrum 4: TB, ell=10
#   Noise bias: 0.000e+00
#   Signal (sim 0): 4.615e+02
#
# --- Processing bin 69 ---
#   Spectrum 4: TB, ell=11
#   Noise bias: 0.000e+00
#   Signal (sim 0): 1.828e+02
#
# --- Processing bin 70 ---
#   Spectrum 4: TB, ell=12
#   Noise bias: 0.000e+00
#   Signal (sim 0): 4.615e+02
#
# --- Processing bin 69 ---
#   Spectrum 4: TB, ell=11
#   Noise bias: 0.000e+00
#   Signal (sim 0): 1.828e+02
#
# --- Processing bin 70 ---
#   Spectrum 4: TB, ell=12
#   Noise bias: 0.000e+00
#   Signal (sim 0): 3.479e+02
#
# --- Processing bin 71 ---
#   Spectrum 4: TB, ell=13
#   Noise bias: 0.000e+00
#   Signal (sim 0): -2.911e+02
#
# --- Processing bin 72 ---
#   Spectrum 4: TB, ell=14
#   Noise bias: 0.000e+00
#   Signal (sim 0): 3.626e+02
#
# --- Processing bin 73 ---
#   Spectrum 4: TB, ell=15
#   Noise bias: 0.000e+00
#   Signal (sim 0): 3.479e+02
#
# --- Processing bin 71 ---
#   Spectrum 4: TB, ell=13
#   Noise bias: 0.000e+00
#   Signal (sim 0): -2.911e+02
#
# --- Processing bin 72 ---
#   Spectrum 4: TB, ell=14
#   Noise bias: 0.000e+00
#   Signal (sim 0): 3.626e+02
#
# --- Processing bin 73 ---
#   Spectrum 4: TB, ell=15
#   Noise bias: 0.000e+00
#   Signal (sim 0): 8.601e+01
#
# --- Processing bin 74 ---
#   Spectrum 4: TB, ell=16
#   Noise bias: 0.000e+00
#   Signal (sim 0): 8.601e+01
#
# --- Processing bin 74 ---
#   Spectrum 4: TB, ell=16
#   Noise bias: 0.000e+00
#   Signal (sim 0): 5.695e+02
#
# --- Processing bin 75 ---
#   Spectrum 5: EB, ell=2
#   Noise bias: 0.000e+00
#   Signal (sim 0): 8.647e+02
#
# --- Processing bin 76 ---
#   Spectrum 5: EB, ell=3
#   Noise bias: 0.000e+00
#   Signal (sim 0): 5.695e+02
#
# --- Processing bin 75 ---
#   Spectrum 5: EB, ell=2
#   Noise bias: 0.000e+00
#   Signal (sim 0): 8.647e+02
#
# --- Processing bin 76 ---
#   Spectrum 5: EB, ell=3
#   Noise bias: 0.000e+00
#   Signal (sim 0): 6.594e+03
#
# --- Processing bin 77 ---
#   Spectrum 5: EB, ell=4
#   Noise bias: 0.000e+00
#   Signal (sim 0): 6.594e+03
#
# --- Processing bin 77 ---
#   Spectrum 5: EB, ell=4
#   Noise bias: 0.000e+00
#   Signal (sim 0): 1.149e+04
#
# --- Processing bin 78 ---
#   Spectrum 5: EB, ell=5
#   Noise bias: 0.000e+00
#   Signal (sim 0): 1.149e+04
#
# --- Processing bin 78 ---
#   Spectrum 5: EB, ell=5
#   Noise bias: 0.000e+00
#   Signal (sim 0): -6.995e+03
#
# --- Processing bin 79 ---
#   Spectrum 5: EB, ell=6
#   Noise bias: 0.000e+00
#   Signal (sim 0): 7.427e+03
#
# --- Processing bin 80 ---
#   Spectrum 5: EB, ell=7
#   Noise bias: 0.000e+00
#   Signal (sim 0): -6.995e+03
#
# --- Processing bin 79 ---
#   Spectrum 5: EB, ell=6
#   Noise bias: 0.000e+00
#   Signal (sim 0): 7.427e+03
#
# --- Processing bin 80 ---
#   Spectrum 5: EB, ell=7
#   Noise bias: 0.000e+00
#   Signal (sim 0): 6.522e+04
#
# --- Processing bin 81 ---
#   Spectrum 5: EB, ell=8
#   Noise bias: 0.000e+00
#   Signal (sim 0): 3.073e+04
#
# --- Processing bin 82 ---
#   Spectrum 5: EB, ell=9
#   Noise bias: 0.000e+00
#   Signal (sim 0): 6.522e+04
#
# --- Processing bin 81 ---
#   Spectrum 5: EB, ell=8
#   Noise bias: 0.000e+00
#   Signal (sim 0): 3.073e+04
#
# --- Processing bin 82 ---
#   Spectrum 5: EB, ell=9
#   Noise bias: 0.000e+00
#   Signal (sim 0): 2.207e+04
#
# --- Processing bin 83 ---
#   Spectrum 5: EB, ell=10
#   Noise bias: 0.000e+00
#   Signal (sim 0): 2.207e+04
#
# --- Processing bin 83 ---
#   Spectrum 5: EB, ell=10
#   Noise bias: 0.000e+00
#   Signal (sim 0): -4.236e+04
#
# --- Processing bin 84 ---
#   Spectrum 5: EB, ell=11
#   Noise bias: 0.000e+00
#   Signal (sim 0): -1.249e+04
#
# --- Processing bin 85 ---
#   Spectrum 5: EB, ell=12
#   Noise bias: 0.000e+00
#   Signal (sim 0): -7.044e+04
#
# --- Processing bin 86 ---
#   Spectrum 5: EB, ell=13
#   Noise bias: 0.000e+00
#   Signal (sim 0): -4.236e+04
#
# --- Processing bin 84 ---
#   Spectrum 5: EB, ell=11
#   Noise bias: 0.000e+00
#   Signal (sim 0): -1.249e+04
#
# --- Processing bin 85 ---
#   Spectrum 5: EB, ell=12
#   Noise bias: 0.000e+00
#   Signal (sim 0): -7.044e+04
#
# --- Processing bin 86 ---
#   Spectrum 5: EB, ell=13
#   Noise bias: 0.000e+00
#   Signal (sim 0): 1.401e+05
#
# --- Processing bin 87 ---
#   Spectrum 5: EB, ell=14
#   Noise bias: 0.000e+00
#   Signal (sim 0): 1.401e+05
#
# --- Processing bin 87 ---
#   Spectrum 5: EB, ell=14
#   Noise bias: 0.000e+00
#   Signal (sim 0): 2.816e+05
#
# --- Processing bin 88 ---
#   Spectrum 5: EB, ell=15
#   Noise bias: 0.000e+00
#   Signal (sim 0): 2.816e+05
#
# --- Processing bin 88 ---
#   Spectrum 5: EB, ell=15
#   Noise bias: 0.000e+00
#   Signal (sim 0): 1.580e+04
#
# --- Processing bin 89 ---
#   Spectrum 5: EB, ell=16
#   Noise bias: 0.000e+00
#   Signal (sim 0): -2.092e+05
#
# Computation completed in 3.35 seconds
#   Noise bias: 0.000e+00
#   Signal (sim 0): 1.580e+04
#
# --- Processing bin 89 ---
#   Spectrum 5: EB, ell=16
#   Noise bias: 0.000e+00
#   Signal (sim 0): -2.092e+05
#
# Computation completed in 3.35 seconds

# %% [markdown]
# ## 12. Final Matrix Multiplication

# %%
print("=== Applying final Fisher matrix multiplication ===")

print("Before final multiplication:")
print(f"y[0] first 5 values: {spectra.y[0, :5]}")
print(f"vecmul first 5 values: {spectra.vecmul[:5]}")
print(f"invfisher[0,0]: {spectra.invfisher[0, 0]:.3e}")

# Method from get_power_spectra() - this might be correct
power_spectra = np.zeros_like(spectra.y)
for field_idx in range(spectra.params.nsims):
    # Element-wise multiplication first, then matrix multiplication
    redy_times_vecmul = spectra.y[field_idx, :] * spectra.vecmul
    power_spectra[field_idx, :] = np.matmul(redy_times_vecmul, spectra.invfisher)

print(f"First 5 values: {power_spectra[0, :5]}")

print("\n✅ Final multiplication completed")
# Out:
# === Applying final Fisher matrix multiplication ===
# Before final multiplication:
# y[0] first 5 values: [0.00535334 0.01545649 0.01109931 0.05058138 0.0475727 ]
# vecmul first 5 values: [1.02655673 0.50316117 0.29398847 0.18959571 0.13013891]
# invfisher[0,0]: 4.261e+05
# First 5 values: [ 731.97438458 2455.78413616  612.50434413 1584.93933177  662.20071028]
#
# ✅ Final multiplication completed

# %% [markdown]
# ## 13. Validate Results and Output

# %%
# Validate results and create diagnostic plots
print("=== Validation and Visualization ===")

# Create diagnostic plots
fig, ax = plt.subplots()

# Define colors and labels
colors = ["red", "dodgerblue", "forestgreen", "orange", "purple", "maroon"]
labels = ["TT", "EE", "BB", "TE", "TB", "EB"]

ell = np.arange(2, spectra.params.lmax + 1)
n_ell = len(ell)

# Plot original fiducial spectra (before normalizations and smoothing)
print("=== Plotting Original Fiducial Spectra ===")

# Load the original input spectra from the file used to generate simulations
original_clfid = np.loadtxt(params.inputclfile)
ell = original_clfid[:, 0].astype(int)

# Map original spectrum columns to labels
spectrum_map = {
    "TT": 1,  # Column 1 in original file
    "EE": 2,  # Column 2
    "BB": 3,  # Column 3
    "TE": 4,  # Column 4
    "TB": 5,  # Column 5 (should be zero)
    "EB": 6,  # Column 6 (should be zero)
}

# Plot original fiducial spectra
for ispec, spec_label in enumerate(
    ["TT", "EE", "BB", "TE", "TB", "EB"]
):  # All TEB spectra
    if spec_label in spectrum_map and spectrum_map[spec_label] < original_clfid.shape[1]:
        col_idx = spectrum_map[spec_label]
        # Extract the relevant ell range
        ell_mask = (ell >= 2) & (ell <= spectra.params.lmax)
        original_spectrum = original_clfid[ell_mask, col_idx]
        ell_plot = ell[ell_mask]

        ax.plot(
            ell_plot,
            original_spectrum,
            "--",
            color=colors[ispec],
            linewidth=2,
            label=f"Fiducial {spec_label}",
            alpha=1,
        )

# Plot computed spectra for comparison
for ispec, spec_label in enumerate(spectra.collection.spectra_labels):
    start_idx = ispec * n_ell
    end_idx = (ispec + 1) * n_ell

    # Plot computed spectrum (average over simulations)
    computed = power_spectra[:, start_idx:end_idx].mean(axis=0)

    ell_mask = (ell >= 2) & (ell <= spectra.params.lmax)
    ell_plot = ell[ell_mask]

    ax.plot(
        ell_plot,
        computed,
        color=colors[ispec],
        label=f"QML Recovered {spec_label}",
        alpha=1,
    )

ax.set_xlabel(r"Multipole $\ell$")
ax.set_ylabel(r"$D_\ell = \frac{{\ell(\ell+1)}}{{2π}}C_\ell$")
ax.set_title("Fiducial vs QML Recovered")
ax.legend(ncol=2)
ax.set_yscale("log")
plt.show()
# Out:
# === Validation and Visualization ===
# === Plotting Original Fiducial Spectra ===

# %%
# Print comparison statistics
print("\n=== Spectrum Comparison Summary ===")
for ispec, spec_label in enumerate(spectra.collection.spectra_labels):
    start_idx = ispec * n_ell
    end_idx = (ispec + 1) * n_ell
    computed = power_spectra[:, start_idx:end_idx].mean(axis=0)

    if spec_label in spectrum_map and spectrum_map[spec_label] < original_clfid.shape[1]:
        col_idx = spectrum_map[spec_label]
        ell_mask = (ell >= 2) & (ell <= spectra.params.lmax)
        original_spectrum = original_clfid[ell_mask, col_idx]

        if spec_label in ["TB", "EB"]:
            print(f"{spec_label}: Original spectrum is zero!")
            mean = np.mean(computed)
            std = np.std(computed)

            print(f"{spec_label}: QML mean = {mean:.3f} ± {std:.3f}")
            continue

        ratio_mean = np.mean(computed / original_spectrum)
        ratio_std = np.std(computed / original_spectrum)

        print(f"{spec_label}: QML/Original ratio = {ratio_mean:.3f} ± {ratio_std:.3f}")
# Out:
# === Spectrum Comparison Summary ===
# TT: QML/Original ratio = 0.999 ± 0.023
# EE: QML/Original ratio = 0.991 ± 0.026
# BB: QML/Original ratio = 0.962 ± 0.181
# TE: QML/Original ratio = 1.003 ± 0.053
# TB: Original spectrum is zero!
# TB: QML mean = -0.002 ± 0.005
# EB: Original spectrum is zero!
# EB: QML mean = -0.000 ± 0.000
